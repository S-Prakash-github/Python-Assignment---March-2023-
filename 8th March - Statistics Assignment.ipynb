# %% [markdown]
# #### Q1. What is the Probability density function?

# %% [markdown]
# A probability density function (PDF) is a mathematical function that describes the probability distribution of a continuous random variable. Unlike discrete random variables, continuous random variables can take on an infinite number of possible values within a given range, making it impossible to assign probabilities to individual values.
#
# Instead, the PDF describes the relative likelihood that the random variable takes on a particular value within a given range. The PDF is defined such that the area under the curve between two values on the x-axis represents the probability that the random variable takes on a value within that range.
#
# Mathematically, the PDF is defined as the derivative of the cumulative distribution function (CDF) of the random variable. The CDF describes the probability that the random variable takes on a value less than or equal to a given value, while the PDF describes the rate at which the probability density changes with respect to the variable's value.

# %% [markdown]
# #### Q2. What are the types of Probability distribution?

# %% [markdown]
# Probablity distribution's are:
# - Normal Distribution: Also known as the Gaussian distribution, it is a continuous probability distribution that is symmetrical and bell-shaped. It is widely used in statistical analysis, particularly in fields such as finance, engineering, and natural sciences.
#
# - Binomial Distribution: This is a discrete probability distribution that describes the number of successes in a fixed number of independent trials, each with the same probability of success. It is commonly used in fields such as psychology, sociology, and biology.
#
# - Poisson Distribution: This is a discrete probability distribution that describes the probability of a given number of events occurring in a fixed interval of time or space, given the average rate at which such events occur. It is widely used in fields such as insurance, finance, and biology.
#
# - Uniform Distribution

# %% [markdown]
# #### Q3. Write a Python function to calculate the probability density function of a normal distribution with given mean and standard deviation at a given point.

# %%
import math

def normal_pdf(x, mu, sigma):
    """Calculates the probability density function of a normal distribution with mean mu and standard deviation sigma at point x."""
    exponent = -1 * ((x - mu) ** 2) / (2 * (sigma ** 2))
    denominator = math.sqrt(2 * math.pi * (sigma ** 2))
    pdf = (1 / denominator) * math.exp(exponent)
    return pdf
pdf = normal_pdf(1, 0, 1)
print(pdf)
# Out:
# 0.24197072451914337

# %% [markdown]
# #### Q4. What are the properties of Binomial distribution? Give two examples of events where binomial distribution can be applied.

# %% [markdown]
# The properties of the Binomial distribution are:
#
# The trials are independent.
# The probability of success (p) is constant for each trial.
# The outcomes of the trials are mutually exclusive and exhaustive.
# The distribution is discrete, meaning that the random variable can only take on integer values.
# The distribution is symmetric when p=0.5.
# The mean of the distribution is μ=np, and the variance is σ^2=np(1-p).

# %% [markdown]
# Two examples of events where the Binomial distribution can be applied are:
#
# A company is conducting a survey to estimate the proportion of its customers who are satisfied with their product. They randomly select 100 customers and ask them if they are satisfied or not. The Binomial distribution can be used to model the number of satisfied customers among the 100 surveyed.
#
# A biologist is studying a population of birds to estimate the proportion of males in the population. She randomly samples 50 birds and determines their sex. The Binomial distribution can be used to model the number of males in the sample.

# %% [markdown]
# #### Q5. Generate a random sample of size 1000 from a binomial distribution with probability of success 0.4 and plot a histogram of the results using matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.random.binomial(1000,0.4,1000)
plt.hist(data , density = True, color = "#0E8388")
# Out:
# (array([0.00060606, 0.00313131, 0.00737374, 0.01818182, 0.02464646,
#         0.0230303 , 0.01474747, 0.00727273, 0.00181818, 0.00020202]),
#  array([352. , 361.9, 371.8, 381.7, 391.6, 401.5, 411.4, 421.3, 431.2,
#         441.1, 451. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #### Q6. Write a Python function to calculate the cumulative distribution function of a Poisson distribution with given mean at a given point

# %%
# defining the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
  
# No of Data points
N = 500
  
# initializing random values
data = np.random.randn(N)
  
# getting data of the histogram
count, bins_count = np.histogram(data, bins=10)
  
# finding the PDF of the histogram using count values
pdf = count / sum(count)
  
# using numpy np.cumsum to calculate the CDF
# We can also find using the PDF values by looping and adding
cdf = np.cumsum(pdf)
  
# plotting PDF and CDF
plt.plot(bins_count[1:], pdf, color="red", label="PDF")
plt.plot(bins_count[1:], cdf, label="CDF")
plt.legend()

# %% [markdown]
# #### Q7. How Binomial distribution different from Poisson distribution?

# %% [markdown]
# Binomial and Poisson distributions are both types of probability distributions used to model the number of events or occurrences in a given situation. However, they differ in certain ways:
#
# - Number of Trials: The Binomial distribution models the number of successes in a fixed number of trials, whereas the Poisson distribution models the number of events in a fixed time interval.
#
#  -Probability of Success: The Binomial distribution assumes a constant probability of success for each trial, whereas the Poisson distribution assumes that the events occur randomly and independently at a fixed average rate.
#
# - Type of Random Variable: The Binomial distribution models a discrete random variable, while the Poisson distribution models a continuous random variable.
#
# - Approximation: In some cases, the Poisson distribution can be used as an approximation of the Binomial distribution when the number of trials is large and the probability of success is small.
#
# - Mean and Variance: For a Binomial distribution, the mean and variance are both equal to np, where n is the number of trials and p is the probability of success. For a Poisson distribution, the mean and variance are both equal to λ, the average rate of occurrence.

# %% [markdown]
# #### Q8. Generate a random sample of size 1000 from a Poisson distribution with mean 5 and calculate the sample mean and variance

# %%
import numpy as np

# Set the seed for reproducibility
np.random.seed(42)

# Generate a random sample of size 1000 from a Poisson distribution with mean 5
sample = np.random.poisson(lam=5, size=1000)

# Calculate the sample mean and variance
sample_mean = np.mean(sample)
sample_variance = np.var(sample, ddof=1)  # set ddof=1 for sample variance

# Print the results
print("Sample mean:", sample_mean)
print("Sample variance:", sample_variance)
# Out:
# Sample mean: 4.985
# Sample variance: 5.001776776776777

# %% [markdown]
# #### Q9. How mean and variance are related in Binomial distribution and Poisson distribution?

# %% [markdown]
# In the case of the Binomial distribution, the mean and variance are related by the formula:
#
# >mean = n * p
#
# >variance = n * p * (1 - p)
#
# where n is the number of trials and p is the probability of success on each trial. This relationship between mean and variance arises from the fact that the Binomial distribution is the sum of independent Bernoulli trials, each with probability p of success, and the variance of the sum of independent random variables is the sum of their variances..
#
# In the case of the Poisson distribution, the mean and variance are equal and are given by the formula:
#
# >mean = variance = lambda
#
# where lambda is the rate parameter of the Poisson distribution. This relationship arises because the Poisson distribution models the number of events that occur in a fixed interval of time or space when the events are rare and random. In this case, the probability of observing more than one event in a small interval of time or space is negligible, and the mean and variance of the number of events are equal to the rate of occurrence.

# %% [markdown]
# #### Q10. In normal distribution with respect to mean position, where does the least frequent data appear?

# %% [markdown]
# In a normal distribution, the least frequent data appears in the tails of the distribution, which are the areas that are farthest from the mean. Specifically, data that is located more than 2 standard deviations away from the mean (either above or below) is considered to be in the tails of the distribution. The probability of observing data in the tails of a normal distribution is relatively small, as most of the data falls within 2 standard deviations of the mean. The probability of observing data beyond 3 standard deviations from the mean is even smaller, and data beyond 4 or more standard deviations from the mean is extremely rare in a normal distribution.
